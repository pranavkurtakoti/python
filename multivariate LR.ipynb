# %% [markdown]
# Multivariate Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/drive/MyDrive/datasheet.csv')
m=data['x1'].values
n=data['x2'].values
o=data['y'].values
print(o)
print(m)
print(n)
m=m.reshape(-1,1)
n=n.reshape(-1,1)
# Out:
# [ 99  95  95  90 105 105  90  92  98  99  99 101  99  94  97  97  99 104
#  104]
# [1000 1200 1000  900 1500 1000 1400 1500 1500 1600 1100 1300 1000 1600
#  1600 1600 1600 2200 1600]
# [ 790 1160  929  865 1140  929 1109 1365 1112 1150  980  990 1112 1252
#  1326 1330 1365 1280 1119]

# %%
plt.scatter(m,n,o)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
slr=LinearRegression()
slr.fit(m,n)
# Out:
# LinearRegression()

# %%
pred=slr.predict(m)

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(n,pred)
plt.plot(m,pred,color='Red',marker='*')
print("MSE:",mse)
print("intercept:",slr.intercept_)
print("slope:",slr.coef_)
# Out:
# MSE: 11593.022744873088
# intercept: [563.5972752]
# slope: [[0.40437602]]
