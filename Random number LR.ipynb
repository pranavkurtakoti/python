# %% [markdown]
# Linear Regression by generating random numbers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
x=np.array([])
y=np.array([])
for i in range(0,6):
  m=random.randint(1,25)
  n=random.randint(1,30)
  x=np.append(x,m)
  y=np.append(y,n)
print(x)
print(y)
x=x.reshape((-1,1))
# Out:
# [ 4. 25. 11.  8.  7. 17.]
# [17. 14.  8. 14. 10. 18.]

# %%
plt.scatter(x,y)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
slr.fit(x,y)
# Out:
# LinearRegression()

# %%
pred=slr.predict(x)

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='Red',marker='*')
print("MSE:",mse)
print("intercept:",slr.intercept_)
print("slope:",slr.coef_)
# Out:
# MSE: 12.314444444444447
# intercept: 12.62
# slope: [0.07333333]
