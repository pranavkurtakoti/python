# %% [markdown]
# My first program

# %%
print("I am pranav")
# Out:
# I am pranav

# %%
print("Black lives matter")
# Out:
# Black lives matter

# %%
a+b
# Out:
# 212

# %% [markdown]
# Variable Declaration in Python
#
# Rule1: variables should always start with an alphabet.
#
# Rule2: variable should not start with some numbers or special characters.
#
# Rule3: variable declaration is case sensitive

# %%
a=121
b=91
sum=a+b

# %%
print("sum of a and b",sum)
# Out:
# sum of a and b 212

# %%
import math
a=122
b=10
c=14
sub=a-b
sub1=a-b-c
mul=a*b
quo=a//b
rem=a%b
square=a*a
squareroot=math.sqrt(a)
cube=b*b*b
print("sub=",sub)
print("sub1=",sub1)
print("mul=",mul)
print("quotient=",quo)
print("remainder=",rem)
print("square=",square)
print("squareroot=",squareroot)
print("cube=",cube)
# Out:
# sub= 112
# sub1= 98
# mul= 1220
# quotient= 12
# remainder= 2
# square= 14884
# squareroot= 11.045361017187261
# cube= 1000

# %% [markdown]
# Data types

# %%
name="pranav"
print(type(name))
# Out:
# <class 'str'>

# %%
name1="pranav & 16"
print(type(name1))
# Out:
# <class 'str'>

# %%
num1=69
num2=58.89
num3=4j
num4=-99
print(type(num1))
print(type(num2))
print(type(num3))
print(type(num4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'int'>

# %% [markdown]
# Sequence data types
#
# list, tuples, range
#
# list:
#
# 1.ordered
#
# 2.mutable
#
# 3.allow duplicates
#
# 4.How do we access elements in tuples
#
# 5.join tuples
#
# 6.multiply tuples
#
# 7.indexing and counting

# %%
lis=['pranav','16','2003','78.5']
type(lis)
print(lis)
# Out:
# ['pranav', '16', '2003', '78.5']

# %%
lis2=['numbers','200','Australia']
print(len(lis))
print(len(lis2))
lis3=lis+lis2
print(lis3)
print(len(lis3))
# Out:
# 4
# 3
# ['pranav', '16', '2003', '78.5', 'numbers', '200', 'Australia']
# 7

# %%
lis2.append('cranberry')
lis2.clear()
print(lis2)
# Out:
# []

# %%
lis2.append('cranberry')
print(lis2)
# Out:
# ['cranberry', 'cranberry']

# %%
 lis.sort()
 lis
# Out:
# ['16', '2003', '78.5', 'pranav']

# %%
tuple1=["dharwad","bengaluru","hubli"]
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
print(tuple1[-2])
tuple6=tuple1+tuple1
print(tuple6)
tuple7=tuple6*2
print(tuple7)
y=tuple7.index('hubli')
print(y)
x=tuple7.count('hubli')
print(x)
# Out:
# dharwad
# bengaluru
# hubli
# bengaluru
# ['dharwad', 'bengaluru', 'hubli', 'dharwad', 'bengaluru', 'hubli']
# ['dharwad', 'bengaluru', 'hubli', 'dharwad', 'bengaluru', 'hubli', 'dharwad', 'bengaluru', 'hubli', 'dharwad', 'bengaluru', 'hubli']
# 2
# 4

# %%
x=("hubli","belgaum","bengaluru")
print(type(x))
# Out:
# <class 'tuple'>

# %%
y=list(x)
y[2]="mumbai"
x=tuple(y)
print(x)
# Out:
# ('hubli', 'belgaum', 'mumbai')
