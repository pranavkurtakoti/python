# %% [markdown]
# Reading a CSV file with data in multiple columns and compute mean, median and mode of each of the columns.

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('/content/drive/MyDrive/Car manufacturing.csv')
print(data)
data.plot()
plt.show()
# Out:
#    Sl.No        Name  Year Make  Quantity   Price
# 0      1      Toyota       2008       400  100000
# 1      2  Volkswagen       2009       355  200000
# 2      3         BMW       2010       618  500000
# 3      4        Merc       2011       255  300000
# 4      5       Honda       2015       185  400000
# 5      6         KIA       2018       344  550000
# 6      7          MG       2020       888  350000

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/Car manufacturing.csv')
data.mean()
# Out:
# <ipython-input-6-6eb930845489>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# Sl.No             4.000000
# Year Make      2013.000000
# Quantity        435.000000
# Price        342857.142857
# dtype: float64

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/Car manufacturing.csv')
data.median()
# Out:
# <ipython-input-7-7032c1a0af67>:3: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# Sl.No             4.0
# Year Make      2011.0
# Quantity        355.0
# Price        350000.0
# dtype: float64

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/Car manufacturing.csv')
data.mode()
# Out:
#    Sl.No        Name  Year Make  Quantity   Price
# 0      1         BMW       2008       185  100000
# 1      2       Honda       2009       255  200000
# 2      3         KIA       2010       344  300000
# 3      4          MG       2011       355  350000
# 4      5        Merc       2015       400  400000
# 5      6      Toyota       2018       618  500000
# 6      7  Volkswagen       2020       888  550000
