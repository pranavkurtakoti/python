# %% [markdown]
# Create a game (like lottery/ rock paper/scissors) and write a python code to record how many times the computer won and the user won in an excel file. Plot the graph showing the success rate of user and computer with different colors

# %%
import random
import csv
from google.colab import files
import pandas as pd

computer_wins = 0
user_wins = 0
game_data = []

while True:
    computer = random.randint(1, 9)
    user_input = int(input("Enter a number between 1 and 9: "))
    print("Computer's number:", computer)
    print("Your guess:", user_input)

    round_result = ""

    if computer > user_input:
        round_result = "Computer won"
        computer_wins += 1
    elif computer == user_input:
        round_result = "Tie"
    else:
        round_result = "You won"
        user_wins += 1

    game_data.append({'User Guess': user_input, 'Computer Number': computer, 'Result': round_result})

    print("User wins:", user_wins, "Computer wins:", computer_wins)

    play_again = input("Do you want to play again? (y/n): ")
    if play_again.lower() != 'y':
        break

# Create a DataFrame from game data
df = pd.DataFrame(game_data)

# Export DataFrame to an Excel file
excel_filename = 'game_results.xlsx'
df.to_excel(excel_filename, index=False)
files.download(excel_filename)
# Out:
# Enter a number between 1 and 9: 6
# Computer's number: 6
# Your guess: 6
# User wins: 0 Computer wins: 0
# Do you want to play again? (y/n): y
# Enter a number between 1 and 9: 5
# Computer's number: 7
# Your guess: 5
# User wins: 0 Computer wins: 1
# Do you want to play again? (y/n): y
# Enter a number between 1 and 9: 9
# Computer's number: 9
# Your guess: 9
# User wins: 0 Computer wins: 1
# Do you want to play again? (y/n): y
# Enter a number between 1 and 9: 2
# Computer's number: 3
# Your guess: 2
# User wins: 0 Computer wins: 2
# Do you want to play again? (y/n): y
# Enter a number between 1 and 9: 4
# Computer's number: 4
# Your guess: 4
# User wins: 0 Computer wins: 2
# Do you want to play again? (y/n): y
# Enter a number between 1 and 9: 6
# Computer's number: 5
# Your guess: 6
# User wins: 1 Computer wins: 2
# Do you want to play again? (y/n): y
# Enter a number between 1 and 9: 1
# Computer's number: 1
# Your guess: 1
# User wins: 1 Computer wins: 2
# Do you want to play again? (y/n): y
# Enter a number between 1 and 9: 7
# Computer's number: 1
# Your guess: 7
# User wins: 2 Computer wins: 2
# Do you want to play again? (y/n): n
